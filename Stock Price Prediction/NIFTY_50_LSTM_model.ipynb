# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense,Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow import keras

# %%
df = pd.read_csv("/content/nifty50 data.csv")
data = df

# %%
df.dropna(inplace = True)

# %%
df = df.drop(['Date', 'Adj Close'], axis = 1)
df.head()
# Out:
#            Open          High           Low         Close    Volume
# 0  10895.799805  10895.799805  10782.599609  10862.599609  506600.0
# 1  10815.400391  11018.549805  10813.799805  10948.250000  517900.0
# 2  10958.099609  10975.650391  10835.900391  10855.500000  548500.0
# 3  10899.200195  11058.049805  10842.950195  11032.450195  482500.0
# 4  11087.900391  11181.450195  11062.799805  11109.650391  538100.0

# %%
plt.figure(figsize = (16,8))
plt.title("Close Price Visualization")
plt.plot(df.Close)

# %%
moving_100 = df['Close'].rolling(100).mean()

# %%
plt.figure(figsize = (16,8))
plt.title("Close Price Visualization")
plt.plot(df['Close'])
plt.plot(moving_100, 'r')

# %%
train = pd.DataFrame(data[0:int(len(data)*0.70)])
test = pd.DataFrame(data[int(len(data)*0.70): int(len(data))])

print(train.shape)
print(test.shape)
# Out:
# (861, 7)
# (370, 7)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
train_close = train.iloc[:, 4:5].values
test_close = test.iloc[:, 4:5].values

# %%
data_training_array = scaler.fit_transform(train_close)
data_test_array = scaler.transform(test_close)

# %%
x_train = []
y_train = []

# %%
for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100: i])
    y_train.append(data_training_array[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_test = []
y_test = []
for i in range(100, data_test_array.shape[0]):
    x_test.append(data_test_array[i-100: i])
    y_test.append(data_test_array[i, 0])

x_test, y_test = np.array(x_test), np.array(y_test)

# %%
x_train.shape
# Out:
# (761, 100, 1)

# %%
model = Sequential()
model.add(LSTM(units = 50, activation = 'relu', return_sequences=True
              ,input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.2))


model.add(LSTM(units = 60, activation = 'relu', return_sequences=True))
model.add(Dropout(0.3))


model.add(LSTM(units = 80, activation = 'relu', return_sequences=True))
model.add(Dropout(0.4))


model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 1))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
print("NaN in train_scaled:", np.isnan(x_train).sum())
print("Infinite in train_scaled:", np.isinf(x_train).sum())
print("NaN in test_scaled:", np.isnan(x_test).sum())
print("Infinite in test_scaled:", np.isinf(x_test).sum())
# Out:
# NaN in train_scaled: 0
# Infinite in train_scaled: 0
# NaN in test_scaled: 0
# Infinite in test_scaled: 0

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['MAE'])
model.fit(x_train, y_train, validation_data = (x_test, y_test) ,epochs = 50)
# Out:
# Epoch 1/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 19s 389ms/step - MAE: 0.4645 - loss: 0.2979 - val_MAE: 0.7097 - val_loss: 0.5148
# Epoch 2/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - MAE: 0.2145 - loss: 0.0650 - val_MAE: 0.3260 - val_loss: 0.1107
# Epoch 3/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - MAE: 0.1318 - loss: 0.0260 - val_MAE: 0.1226 - val_loss: 0.0168
# Epoch 4/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - MAE: 0.1136 - loss: 0.0196 - val_MAE: 0.0518 - val_loss: 0.0045
# Epoch 5/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - MAE: 0.0982 - loss: 0.0160 - val_MAE: 0.1137 - val_loss: 0.0149
# Epoch 6/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - MAE: 0.0967 - loss: 0.0154 - val_MAE: 0.1563 - val_loss: 0.0262
# Epoch 7/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - MAE: 0.0985 - loss: 0.0147 - val_MAE: 0.0717 - val_loss: 0.0070
# Epoch 8/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - MAE: 0.0926 - loss: 0.0143 - val_MAE: 0.1025 - val_loss: 0.0123
# Epoch 9/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - MAE: 0.0888 - loss: 0.0137 - val_MAE: 0.0898 - val_loss: 0.0098
# Epoch 10/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - MAE: 0.0860 - loss: 0.0124 - val_MAE: 0.1231 - val_loss: 0.0170
# Epoch 11/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - MAE: 0.0839 - loss: 0.0119 - val_MAE: 0.1542 - val_loss: 0.0259
# Epoch 12/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - MAE: 0.0799 - loss: 0.0110 - val_MAE: 0.2050 - val_loss: 0.0446
# Epoch 13/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - MAE: 0.0824 - loss: 0.0112 - val_MAE: 0.1611 - val_loss: 0.0284
# Epoch 14/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - MAE: 0.0853 - loss: 0.0128 - val_MAE: 0.1434 - val_loss: 0.0230
# Epoch 15/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - MAE: 0.0826 - loss: 0.0121 - val_MAE: 0.1448 - val_loss: 0.0236
# Epoch 16/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - MAE: 0.0785 - loss: 0.0099 - val_MAE: 0.1374 - val_loss: 0.0215
# Epoch 17/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - MAE: 0.0780 - loss: 0.0107 - val_MAE: 0.1888 - val_loss: 0.0389
# Epoch 18/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - MAE: 0.0770 - loss: 0.0100 - val_MAE: 0.1933 - val_loss: 0.0409
# Epoch 19/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - MAE: 0.0812 - loss: 0.0110 - val_MAE: 0.2030 - val_loss: 0.0443
# Epoch 20/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - MAE: 0.0841 - loss: 0.0118 - val_MAE: 0.2147 - val_loss: 0.0500
# Epoch 21/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - MAE: 0.0747 - loss: 0.0097 - val_MAE: 0.1875 - val_loss: 0.0390
# Epoch 22/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - MAE: 0.0771 - loss: 0.0099 - val_MAE: 0.2157 - val_loss: 0.0508
# Epoch 23/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - MAE: 0.0723 - loss: 0.0087 - val_MAE: 0.2566 - val_loss: 0.0707
# Epoch 24/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - MAE: 0.0741 - loss: 0.0092 - val_MAE: 0.2112 - val_loss: 0.0489
# Epoch 25/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - MAE: 0.0702 - loss: 0.0082 - val_MAE: 0.1945 - val_loss: 0.0420
# Epoch 26/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - MAE: 0.0733 - loss: 0.0089 - val_MAE: 0.1549 - val_loss: 0.0279
# Epoch 27/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - MAE: 0.0712 - loss: 0.0085 - val_MAE: 0.2241 - val_loss: 0.0550
# Epoch 28/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - MAE: 0.0680 - loss: 0.0077 - val_MAE: 0.1788 - val_loss: 0.0363
# Epoch 29/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - MAE: 0.0756 - loss: 0.0100 - val_MAE: 0.2145 - val_loss: 0.0508
# Epoch 30/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - MAE: 0.0645 - loss: 0.0070 - val_MAE: 0.2256 - val_loss: 0.0555
# Epoch 31/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - MAE: 0.0731 - loss: 0.0087 - val_MAE: 0.2252 - val_loss: 0.0558
# Epoch 32/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - MAE: 0.0721 - loss: 0.0086 - val_MAE: 0.2096 - val_loss: 0.0491
# Epoch 33/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - MAE: 0.0680 - loss: 0.0079 - val_MAE: 0.2072 - val_loss: 0.0481
# Epoch 34/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - MAE: 0.0691 - loss: 0.0081 - val_MAE: 0.2147 - val_loss: 0.0513
# Epoch 35/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - MAE: 0.0679 - loss: 0.0079 - val_MAE: 0.2533 - val_loss: 0.0698
# Epoch 36/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - MAE: 0.0697 - loss: 0.0088 - val_MAE: 0.2378 - val_loss: 0.0624
# Epoch 37/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - MAE: 0.0683 - loss: 0.0079 - val_MAE: 0.1639 - val_loss: 0.0320
# Epoch 38/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - MAE: 0.0692 - loss: 0.0088 - val_MAE: 0.1984 - val_loss: 0.0449
# Epoch 39/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - MAE: 0.0721 - loss: 0.0095 - val_MAE: 0.1924 - val_loss: 0.0426
# Epoch 40/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - MAE: 0.0660 - loss: 0.0073 - val_MAE: 0.2137 - val_loss: 0.0515
# Epoch 41/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - MAE: 0.0667 - loss: 0.0077 - val_MAE: 0.1776 - val_loss: 0.0369
# Epoch 42/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - MAE: 0.0682 - loss: 0.0082 - val_MAE: 0.2023 - val_loss: 0.0463
# Epoch 43/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - MAE: 0.0658 - loss: 0.0072 - val_MAE: 0.2355 - val_loss: 0.0614
# Epoch 44/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - MAE: 0.0613 - loss: 0.0067 - val_MAE: 0.1781 - val_loss: 0.0368
# Epoch 45/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - MAE: 0.0678 - loss: 0.0074 - val_MAE: 0.1502 - val_loss: 0.0273
# Epoch 46/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - MAE: 0.0679 - loss: 0.0076 - val_MAE: 0.1974 - val_loss: 0.0448
# Epoch 47/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - MAE: 0.0646 - loss: 0.0074 - val_MAE: 0.1625 - val_loss: 0.0319
# Epoch 48/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - MAE: 0.0630 - loss: 0.0067 - val_MAE: 0.1909 - val_loss: 0.0417
# Epoch 49/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - MAE: 0.0662 - loss: 0.0078 - val_MAE: 0.1993 - val_loss: 0.0447
# Epoch 50/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - MAE: 0.0683 - loss: 0.0081 - val_MAE: 0.2200 - val_loss: 0.0545

# %%
import tensorflow as tf
tf.keras.models.save_model(model, 'my_model.keras')

# %%
past_100_days = pd.DataFrame(train_close[-100:])

# %%
test_df = pd.DataFrame(test_close)

# %%
import pandas as pd
final_df = pd.concat([past_100_days, test_df], ignore_index=True)

# %%
input_data = scaler.fit_transform(final_df)
input_data
# Out:
# array([[0.10346903],
#        [0.10222389],
#        [0.09841577],
#        [0.1196966 ],
#        [0.12391977],
#        [0.13649178],
#        [0.15281113],
#        [0.14471857],
#        [0.12929654],
#        [0.08699711],
#        [0.09815329],
#        [0.12183262],
#        [0.10988306],
#        [0.09907493],
#        [0.06215823],
#        [0.02419211],
#        [0.02310575],
#        [0.00494336],
#        [0.        ],
#        [0.03371863],
#        [0.00845254],
#        [0.05568318],
#        [0.06270153],
#        [0.06060818],
#        [0.05161854],
#        [0.0201947 ],
#        [0.03728884],
#        [0.02395396],
#        [0.04486861],
#        [0.06026037],
#        [0.0816387 ],
#        [0.08472687],
#        [0.0910372 ],
#        [0.09254481],
#        [0.11139663],
#        [0.10231544],
#        [0.1121533 ],
#        [0.1182381 ],
#        [0.14574987],
#        [0.16200818],
#        [0.15437334],
#        [0.15069323],
#        [0.15856004],
#        [0.16901438],
#        [0.16342401],
#        [0.1477028 ],
#        [0.18694457],
#        [0.18443641],
#        [0.19349925],
#        [0.19426211],
#        [0.18623677],
#        [0.18181216],
#        [0.16378399],
#        [0.17406741],
#        [0.17688095],
#        [0.20334926],
#        [0.20684628],
#        [0.2129492 ],
#        [0.21969913],
#        [0.23682377],
#        [0.24343328],
#        [0.22922564],
#        [0.22982997],
#        [0.22271387],
#        [0.21267457],
#        [0.21863708],
#        [0.20487499],
#        [0.20494222],
#        [0.21847234],
#        [0.22485609],
#        [0.19490292],
#        [0.17709455],
#        [0.1955802 ],
#        [0.19129004],
#        [0.16856262],
#        [0.15980494],
#        [0.12067926],
#        [0.14604285],
#        [0.16040927],
#        [0.159213  ],
#        [0.167574  ],
#        [0.15711369],
#        [0.16836118],
#        [0.17264562],
#        [0.14950316],
#        [0.14330274],
#        [0.12710545],
#        [0.15661306],
#        [0.13378218],
#        [0.13153006],
#        [0.12695287],
#        [0.13896347],
#        [0.13142636],
#        [0.15076666],
#        [0.16444315],
#        [0.1574248 ],
#        [0.14763581],
#        [0.15873096],
#        [0.15870045],
#        [0.13107234],
#        [0.0959684 ],
#        [0.10141216],
#        [0.10302347],
#        [0.09742714],
#        [0.09670695],
#        [0.12644652],
#        [0.11552826],
#        [0.11026759],
#        [0.12860066],
#        [0.13125543],
#        [0.12674547],
#        [0.11629732],
#        [0.13569841],
#        [0.14619543],
#        [0.14863659],
#        [0.1374499 ],
#        [0.12529293],
#        [0.12310804],
#        [0.08985952],
#        [0.08460481],
#        [0.07905736],
#        [0.0701347 ],
#        [0.05930202],
#        [0.07723864],
#        [0.06149311],
#        [0.09474782],
#        [0.10904081],
#        [0.11428336],
#        [0.09416804],
#        [0.07260042],
#        [0.04103617],
#        [0.02748769],
#        [0.01880319],
#        [0.02044478],
#        [0.0344145 ],
#        [0.02078664],
#        [0.03532374],
#        [0.04074318],
#        [0.0315888 ],
#        [0.01549545],
#        [0.02045694],
#        [0.01630695],
#        [0.03205248],
#        [0.06611297],
#        [0.0707879 ],
#        [0.09019518],
#        [0.09533379],
#        [0.0983731 ],
#        [0.11036533],
#        [0.12136274],
#        [0.12326681],
#        [0.10847939],
#        [0.10277936],
#        [0.09772609],
#        [0.09842173],
#        [0.0983731 ],
#        [0.11294072],
#        [0.11609588],
#        [0.12150912],
#        [0.13389208],
#        [0.15219464],
#        [0.16228282],
#        [0.15522775],
#        [0.17548348],
#        [0.15268288],
#        [0.17653313],
#        [0.17672218],
#        [0.1827214 ],
#        [0.18051219],
#        [0.18268492],
#        [0.19294379],
#        [0.17923057],
#        [0.16644496],
#        [0.16012224],
#        [0.16908757],
#        [0.18263605],
#        [0.18673716],
#        [0.17909636],
#        [0.18345995],
#        [0.20521065],
#        [0.21733115],
#        [0.22162751],
#        [0.20948889],
#        [0.20379482],
#        [0.20945218],
#        [0.21674517],
#        [0.21737382],
#        [0.2329241 ],
#        [0.22171309],
#        [0.21302859],
#        [0.21767896],
#        [0.23167301],
#        [0.23652483],
#        [0.22824917],
#        [0.24508107],
#        [0.23646976],
#        [0.24394583],
#        [0.24884652],
#        [0.23839837],
#        [0.2254907 ],
#        [0.22862751],
#        [0.24403142],
#        [0.26291375],
#        [0.28939446],
#        [0.30568926],
#        [0.31379994],
#        [0.31495949],
#        [0.32701896],
#        [0.3068183 ],
#        [0.30975985],
#        [0.31995173],
#        [0.31322636],
#        [0.31682088],
#        [0.33522119],
#        [0.35315757],
#        [0.35777147],
#        [0.36801222],
#        [0.38583274],
#        [0.35725272],
#        [0.34838513],
#        [0.34939212],
#        [0.36131736],
#        [0.3468656 ],
#        [0.34517514],
#        [0.35832693],
#        [0.35585525],
#        [0.33058917],
#        [0.31290286],
#        [0.32942341],
#        [0.3392248 ],
#        [0.33599621],
#        [0.34352735],
#        [0.33260909],
#        [0.31859693],
#        [0.31935979],
#        [0.32307638],
#        [0.31090105],
#        [0.30417568],
#        [0.31436136],
#        [0.31470918],
#        [0.32051315],
#        [0.31351911],
#        [0.29876244],
#        [0.30367529],
#        [0.30814258],
#        [0.30872832],
#        [0.29729774],
#        [0.31945134],
#        [0.3308638 ],
#        [0.33649064],
#        [0.3409031 ],
#        [0.35506187],
#        [0.3664009 ],
#        [0.38793205],
#        [0.38754752],
#        [0.3969217 ],
#        [0.40096178],
#        [0.41185549],
#        [0.40464809],
#        [0.3763427 ],
#        [0.35692922],
#        [0.34861709],
#        [0.34865381],
#        [0.34745134],
#        [0.35376786],
#        [0.33022299],
#        [0.34422919],
#        [0.3308576 ],
#        [0.31954884],
#        [0.33293259],
#        [0.34608438],
#        [0.32885579],
#        [0.35052116],
#        [0.36535125],
#        [0.36323358],
#        [0.35799127],
#        [0.35563545],
#        [0.36536961],
#        [0.34823256],
#        [0.342569  ],
#        [0.33255426],
#        [0.30070918],
#        [0.28122871],
#        [0.2488954 ],
#        [0.27208649],
#        [0.2835173 ],
#        [0.27603503],
#        [0.26499494],
#        [0.28258351],
#        [0.29446584],
#        [0.31657677],
#        [0.31596028],
#        [0.32045212],
#        [0.314569  ],
#        [0.31823671],
#        [0.32045832],
#        [0.34876347],
#        [0.35971821],
#        [0.35564165],
#        [0.35102775],
#        [0.36193981],
#        [0.36541228],
#        [0.36421005],
#        [0.36331893],
#        [0.37491448],
#        [0.4001684 ],
#        [0.40462973],
#        [0.4210771 ],
#        [0.4722074 ],
#        [0.49274968],
#        [0.50283166],
#        [0.49837057],
#        [0.50670105],
#        [0.51008197],
#        [0.49901137],
#        [0.50144634],
#        [0.53273596],
#        [0.566174  ],
#        [0.56153578],
#        [0.5657406 ],
#        [0.52876311],
#        [0.54156708],
#        [0.55308324],
#        [0.56430641],
#        [0.59035372],
#        [0.60548276],
#        [0.59970954],
#        [0.60099115],
#        [0.59170256],
#        [0.57358285],
#        [0.59082359],
#        [0.59719518],
#        [0.57305194],
#        [0.57693945],
#        [0.58595342],
#        [0.58943208],
#        [0.61962341],
#        [0.64438887],
#        [0.63643695],
#        [0.58024719],
#        [0.56685748],
#        [0.58640518],
#        [0.53958363],
#        [0.5658443 ],
#        [0.55347373],
#        [0.60046621],
#        [0.57416262],
#        [0.59901366],
#        [0.59556551],
#        [0.61464953],
#        [0.60462835],
#        [0.6238771 ],
#        [0.62401132],
#        [0.59806771],
#        [0.60594667],
#        [0.58563015],
#        [0.60115588],
#        [0.61297123],
#        [0.62160066],
#        [0.63746205],
#        [0.64741601],
#        [0.65653368],
#        [0.63921378],
#        [0.65903587],
#        [0.65845609],
#        [0.64739169],
#        [0.6567046 ],
#        [0.62653187],
#        [0.63039506],
#        [0.67384165],
#        [0.6820012 ],
#        [0.67598387],
#        [0.69035624],
#        [0.69273638],
#        [0.67309714],
#        [0.67346928],
#        [0.63221354],
#        [0.65039428],
#        [0.63534439],
#        [0.63929293],
#        [0.61021252],
#        [0.61285513],
#        [0.63395287],
#        [0.64430352],
#        [0.63306795],
#        [0.64758694],
#        [0.67239531],
#        [0.68888534],
#        [0.68782353],
#        [0.6855471 ],
#        [0.69531177],
#        [0.69519567],
#        [0.71382197],
#        [0.7109474 ],
#        [0.72450208],
#        [0.69589154],
#        [0.66575528],
#        [0.65054685],
#        [0.63198778],
#        [0.65043695],
#        [0.67355486],
#        [0.67741186],
#        [0.68161071],
#        [0.70211032],
#        [0.68375269],
#        [0.71102678],
#        [0.70632134],
#        [0.71161252],
#        [0.69057581],
#        [0.68652952],
#        [0.66941703],
#        [0.66941703],
#        [0.62730689],
#        [0.6392319 ],
#        [0.64519464],
#        [0.65908474],
#        [0.65697328],
#        [0.6817876 ],
#        [0.68938574],
#        [0.69706945],
#        [0.70546097],
#        [0.75060421],
#        [0.7493164 ],
#        [0.74630761],
#        [0.74090057],
#        [0.71850882],
#        [0.69213825],
#        [0.69727066],
#        [0.78676401],
#        [0.61839663],
#        [0.70821324],
#        [0.73275317],
#        [0.78996804],
#        [0.78619019],
#        [0.78687987],
#        [0.79397141],
#        [0.80324189],
#        [0.81138309],
#        [0.82264917],
#        [0.81753488],
#        [0.82375986],
#        [0.81571616],
#        [0.82020181],
#        [0.84259356],
#        [0.86059717],
#        [0.88204273],
#        [0.87790491],
#        [0.89393723],
#        [0.89172802],
#        [0.91158086],
#        [0.91349112],
#        [0.91613969],
#        [0.91573704],
#        [0.92948673],
#        [0.91621288],
#        [0.91517539],
#        [0.9379028 ],
#        [0.94822269],
#        [0.95143292],
#        [0.97436154],
#        [0.94141198],
#        [0.93876937],
#        [0.9350833 ],
#        [0.92708228],
#        [0.926179  ],
#        [0.97851153],
#        [0.9786641 ],
#        [0.98125188],
#        [0.99270701],
#        [1.        ]])

# %%
y_pred = model.predict(x_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 187ms/step

# %%
scale_factor = 1/0.00985902
y_pred = y_pred * scale_factor
y_test = y_test * scale_factor

# %%
plt.figure(figsize = (12,6))
plt.plot(y_test, 'b', label = "Original Price")
plt.plot(y_pred, 'r', label = "Predicted Price")
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
print("Mean absolute error on test set: ", mae)
# Out:
# Mean absolute error on test set:  22.31537438194324
