# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
train = pd.read_csv('/content/sample_data/california_housing_train.csv')
test = pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
# [17000 rows x 9 columns]

# %%
std = StandardScaler()
train = std.fit_transform(train)
test = std.fit_transform(test)

# %%
train_df = pd.DataFrame(train, columns=['longitude', 'latitude', 'housing_median_age',
                                       'total_rooms', 'total_bedrooms', 'population',
                                       'households', 'median_income', 'median_house_value'])
test_df = pd.DataFrame(test, columns=['longitude', 'latitude', 'housing_median_age',
                                      'total_rooms', 'total_bedrooms', 'population',
                                      'households', 'median_income', 'median_house_value'])
X_train = train_df.drop('median_house_value', axis=1)
y_train = train_df['median_house_value']
X_test = test_df.drop('median_house_value', axis=1)
y_test = test_df['median_house_value']

# %%
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(8,)))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# %%
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# %%
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2,verbose = 2)
# Out:
# Epoch 1/100
# 425/425 - 2s - loss: 0.3628 - mae: 0.4318 - val_loss: 0.5411 - val_mae: 0.5357 - 2s/epoch - 5ms/step
# Epoch 2/100
# 425/425 - 1s - loss: 0.2660 - mae: 0.3649 - val_loss: 0.4802 - val_mae: 0.5023 - 1s/epoch - 3ms/step
# Epoch 3/100
# 425/425 - 1s - loss: 0.2452 - mae: 0.3462 - val_loss: 0.4541 - val_mae: 0.4901 - 995ms/epoch - 2ms/step
# Epoch 4/100
# 425/425 - 1s - loss: 0.2361 - mae: 0.3390 - val_loss: 0.4476 - val_mae: 0.5027 - 681ms/epoch - 2ms/step
# Epoch 5/100
# 425/425 - 1s - loss: 0.2266 - mae: 0.3297 - val_loss: 0.4757 - val_mae: 0.5343 - 695ms/epoch - 2ms/step
# Epoch 6/100
# 425/425 - 1s - loss: 0.2210 - mae: 0.3253 - val_loss: 0.4413 - val_mae: 0.4888 - 720ms/epoch - 2ms/step
# Epoch 7/100
# 425/425 - 1s - loss: 0.2157 - mae: 0.3212 - val_loss: 0.4506 - val_mae: 0.5161 - 707ms/epoch - 2ms/step
# Epoch 8/100
# 425/425 - 1s - loss: 0.2111 - mae: 0.3165 - val_loss: 0.4698 - val_mae: 0.5530 - 736ms/epoch - 2ms/step
# Epoch 9/100
# 425/425 - 1s - loss: 0.2109 - mae: 0.3171 - val_loss: 0.4707 - val_mae: 0.5277 - 681ms/epoch - 2ms/step
# Epoch 10/100
# 425/425 - 1s - loss: 0.2072 - mae: 0.3128 - val_loss: 0.3952 - val_mae: 0.4714 - 705ms/epoch - 2ms/step
# Epoch 11/100
# 425/425 - 1s - loss: 0.2048 - mae: 0.3106 - val_loss: 0.4073 - val_mae: 0.4899 - 682ms/epoch - 2ms/step
# Epoch 12/100
# 425/425 - 1s - loss: 0.2057 - mae: 0.3108 - val_loss: 0.4413 - val_mae: 0.5251 - 700ms/epoch - 2ms/step
# Epoch 13/100
# 425/425 - 1s - loss: 0.2009 - mae: 0.3068 - val_loss: 0.4638 - val_mae: 0.5209 - 718ms/epoch - 2ms/step
# Epoch 14/100
# 425/425 - 1s - loss: 0.1998 - mae: 0.3061 - val_loss: 0.4382 - val_mae: 0.5159 - 707ms/epoch - 2ms/step
# Epoch 15/100
# 425/425 - 1s - loss: 0.2008 - mae: 0.3071 - val_loss: 0.4140 - val_mae: 0.4943 - 720ms/epoch - 2ms/step
# Epoch 16/100
# 425/425 - 1s - loss: 0.1991 - mae: 0.3055 - val_loss: 0.4124 - val_mae: 0.5064 - 696ms/epoch - 2ms/step
# Epoch 17/100
# 425/425 - 1s - loss: 0.1964 - mae: 0.3036 - val_loss: 0.4281 - val_mae: 0.5062 - 956ms/epoch - 2ms/step
# Epoch 18/100
# 425/425 - 1s - loss: 0.1956 - mae: 0.3030 - val_loss: 0.4018 - val_mae: 0.4821 - 1s/epoch - 3ms/step
# Epoch 19/100
# 425/425 - 1s - loss: 0.1943 - mae: 0.3020 - val_loss: 0.3960 - val_mae: 0.4922 - 1s/epoch - 3ms/step
# Epoch 20/100
# 425/425 - 1s - loss: 0.1930 - mae: 0.2998 - val_loss: 0.4212 - val_mae: 0.5117 - 752ms/epoch - 2ms/step
# Epoch 21/100
# 425/425 - 1s - loss: 0.1919 - mae: 0.2983 - val_loss: 0.4045 - val_mae: 0.4946 - 719ms/epoch - 2ms/step
# Epoch 22/100
# 425/425 - 1s - loss: 0.1912 - mae: 0.2987 - val_loss: 0.4264 - val_mae: 0.5188 - 678ms/epoch - 2ms/step
# Epoch 23/100
# 425/425 - 1s - loss: 0.1907 - mae: 0.2977 - val_loss: 0.4024 - val_mae: 0.4891 - 702ms/epoch - 2ms/step
# Epoch 24/100
# 425/425 - 1s - loss: 0.1916 - mae: 0.2995 - val_loss: 0.4498 - val_mae: 0.5328 - 710ms/epoch - 2ms/step
# Epoch 25/100
# 425/425 - 1s - loss: 0.1907 - mae: 0.2966 - val_loss: 0.3910 - val_mae: 0.4781 - 695ms/epoch - 2ms/step
# Epoch 26/100
# 425/425 - 1s - loss: 0.1879 - mae: 0.2944 - val_loss: 0.4344 - val_mae: 0.5156 - 675ms/epoch - 2ms/step
# Epoch 27/100
# 425/425 - 1s - loss: 0.1866 - mae: 0.2946 - val_loss: 0.4141 - val_mae: 0.5020 - 718ms/epoch - 2ms/step
# Epoch 28/100
# 425/425 - 1s - loss: 0.1868 - mae: 0.2942 - val_loss: 0.4387 - val_mae: 0.5188 - 714ms/epoch - 2ms/step
# Epoch 29/100
# 425/425 - 1s - loss: 0.1870 - mae: 0.2951 - val_loss: 0.4123 - val_mae: 0.4936 - 723ms/epoch - 2ms/step
# Epoch 30/100
# 425/425 - 1s - loss: 0.1856 - mae: 0.2927 - val_loss: 0.4248 - val_mae: 0.5079 - 667ms/epoch - 2ms/step
# Epoch 31/100
# 425/425 - 1s - loss: 0.1842 - mae: 0.2912 - val_loss: 0.4584 - val_mae: 0.5441 - 702ms/epoch - 2ms/step
# Epoch 32/100
# 425/425 - 1s - loss: 0.1848 - mae: 0.2923 - val_loss: 0.4328 - val_mae: 0.5295 - 721ms/epoch - 2ms/step
# Epoch 33/100
# 425/425 - 1s - loss: 0.1852 - mae: 0.2923 - val_loss: 0.3826 - val_mae: 0.4828 - 680ms/epoch - 2ms/step
# Epoch 34/100
# 425/425 - 1s - loss: 0.1833 - mae: 0.2908 - val_loss: 0.3832 - val_mae: 0.4752 - 1s/epoch - 2ms/step
# Epoch 35/100
# 425/425 - 1s - loss: 0.1815 - mae: 0.2886 - val_loss: 0.4797 - val_mae: 0.5587 - 1s/epoch - 3ms/step
# Epoch 36/100
# 425/425 - 1s - loss: 0.1816 - mae: 0.2884 - val_loss: 0.4630 - val_mae: 0.5463 - 1s/epoch - 3ms/step
# Epoch 37/100
# 425/425 - 1s - loss: 0.1815 - mae: 0.2895 - val_loss: 0.4810 - val_mae: 0.5522 - 736ms/epoch - 2ms/step
# Epoch 38/100
# 425/425 - 1s - loss: 0.1812 - mae: 0.2881 - val_loss: 0.5200 - val_mae: 0.5843 - 693ms/epoch - 2ms/step
# Epoch 39/100
# 425/425 - 1s - loss: 0.1799 - mae: 0.2864 - val_loss: 0.4158 - val_mae: 0.5080 - 696ms/epoch - 2ms/step
# Epoch 40/100
# 425/425 - 1s - loss: 0.1790 - mae: 0.2871 - val_loss: 0.4482 - val_mae: 0.5363 - 681ms/epoch - 2ms/step
# Epoch 41/100
# 425/425 - 1s - loss: 0.1790 - mae: 0.2865 - val_loss: 0.4205 - val_mae: 0.4914 - 718ms/epoch - 2ms/step
# Epoch 42/100
# 425/425 - 1s - loss: 0.1807 - mae: 0.2879 - val_loss: 0.4034 - val_mae: 0.4966 - 730ms/epoch - 2ms/step
# Epoch 43/100
# 425/425 - 1s - loss: 0.1779 - mae: 0.2852 - val_loss: 0.4620 - val_mae: 0.5387 - 704ms/epoch - 2ms/step
# Epoch 44/100
# 425/425 - 1s - loss: 0.1782 - mae: 0.2852 - val_loss: 0.4132 - val_mae: 0.4990 - 680ms/epoch - 2ms/step
# Epoch 45/100
# 425/425 - 1s - loss: 0.1797 - mae: 0.2866 - val_loss: 0.4505 - val_mae: 0.5240 - 687ms/epoch - 2ms/step
# Epoch 46/100
# 425/425 - 1s - loss: 0.1784 - mae: 0.2857 - val_loss: 0.3991 - val_mae: 0.4874 - 695ms/epoch - 2ms/step
# Epoch 47/100
# 425/425 - 1s - loss: 0.1768 - mae: 0.2846 - val_loss: 0.3882 - val_mae: 0.4918 - 676ms/epoch - 2ms/step
# Epoch 48/100
# 425/425 - 1s - loss: 0.1772 - mae: 0.2845 - val_loss: 0.4503 - val_mae: 0.5129 - 710ms/epoch - 2ms/step
# Epoch 49/100
# 425/425 - 1s - loss: 0.1752 - mae: 0.2831 - val_loss: 0.3871 - val_mae: 0.4816 - 702ms/epoch - 2ms/step
# Epoch 50/100
# 425/425 - 1s - loss: 0.1747 - mae: 0.2820 - val_loss: 0.4488 - val_mae: 0.5283 - 712ms/epoch - 2ms/step
# Epoch 51/100
# 425/425 - 1s - loss: 0.1755 - mae: 0.2819 - val_loss: 0.3836 - val_mae: 0.4712 - 1s/epoch - 2ms/step
# Epoch 52/100
# 425/425 - 1s - loss: 0.1765 - mae: 0.2849 - val_loss: 0.3922 - val_mae: 0.4893 - 1s/epoch - 3ms/step
# Epoch 53/100
# 425/425 - 1s - loss: 0.1752 - mae: 0.2822 - val_loss: 0.3929 - val_mae: 0.4916 - 1s/epoch - 3ms/step
# Epoch 54/100
# 425/425 - 1s - loss: 0.1748 - mae: 0.2826 - val_loss: 0.3833 - val_mae: 0.4654 - 742ms/epoch - 2ms/step
# Epoch 55/100
# 425/425 - 1s - loss: 0.1744 - mae: 0.2825 - val_loss: 0.3898 - val_mae: 0.4818 - 714ms/epoch - 2ms/step
# Epoch 56/100
# 425/425 - 1s - loss: 0.1737 - mae: 0.2818 - val_loss: 0.4003 - val_mae: 0.4940 - 705ms/epoch - 2ms/step
# Epoch 57/100
# 425/425 - 1s - loss: 0.1738 - mae: 0.2821 - val_loss: 0.3770 - val_mae: 0.4705 - 703ms/epoch - 2ms/step
# Epoch 58/100
# 425/425 - 1s - loss: 0.1728 - mae: 0.2809 - val_loss: 0.3998 - val_mae: 0.4912 - 691ms/epoch - 2ms/step
# Epoch 59/100
# 425/425 - 1s - loss: 0.1731 - mae: 0.2810 - val_loss: 0.3971 - val_mae: 0.4908 - 733ms/epoch - 2ms/step
# Epoch 60/100
# 425/425 - 1s - loss: 0.1715 - mae: 0.2799 - val_loss: 0.3840 - val_mae: 0.4845 - 683ms/epoch - 2ms/step
# Epoch 61/100
# 425/425 - 1s - loss: 0.1720 - mae: 0.2801 - val_loss: 0.4113 - val_mae: 0.5033 - 715ms/epoch - 2ms/step
# Epoch 62/100
# 425/425 - 1s - loss: 0.1719 - mae: 0.2809 - val_loss: 0.3870 - val_mae: 0.4834 - 691ms/epoch - 2ms/step
# Epoch 63/100
# 425/425 - 1s - loss: 0.1709 - mae: 0.2785 - val_loss: 0.3632 - val_mae: 0.4571 - 709ms/epoch - 2ms/step
# Epoch 64/100
# 425/425 - 1s - loss: 0.1728 - mae: 0.2807 - val_loss: 0.3819 - val_mae: 0.4608 - 723ms/epoch - 2ms/step
# Epoch 65/100
# 425/425 - 1s - loss: 0.1723 - mae: 0.2794 - val_loss: 0.4124 - val_mae: 0.4853 - 698ms/epoch - 2ms/step
# Epoch 66/100
# 425/425 - 1s - loss: 0.1708 - mae: 0.2790 - val_loss: 0.3910 - val_mae: 0.4687 - 672ms/epoch - 2ms/step
# Epoch 67/100
# 425/425 - 1s - loss: 0.1709 - mae: 0.2777 - val_loss: 0.3932 - val_mae: 0.4801 - 715ms/epoch - 2ms/step
# Epoch 68/100
# 425/425 - 1s - loss: 0.1707 - mae: 0.2782 - val_loss: 0.3951 - val_mae: 0.4910 - 1s/epoch - 3ms/step
# Epoch 69/100
# 425/425 - 1s - loss: 0.1697 - mae: 0.2774 - val_loss: 0.3908 - val_mae: 0.4879 - 1s/epoch - 3ms/step
# Epoch 70/100
# 425/425 - 1s - loss: 0.1691 - mae: 0.2767 - val_loss: 0.4070 - val_mae: 0.5025 - 1s/epoch - 3ms/step
# Epoch 71/100
# 425/425 - 1s - loss: 0.1705 - mae: 0.2788 - val_loss: 0.4438 - val_mae: 0.4943 - 748ms/epoch - 2ms/step
# Epoch 72/100
# 425/425 - 1s - loss: 0.1687 - mae: 0.2774 - val_loss: 0.3928 - val_mae: 0.4771 - 691ms/epoch - 2ms/step
# Epoch 73/100
# 425/425 - 1s - loss: 0.1685 - mae: 0.2773 - val_loss: 0.4148 - val_mae: 0.4887 - 706ms/epoch - 2ms/step
# Epoch 74/100
# 425/425 - 1s - loss: 0.1693 - mae: 0.2771 - val_loss: 0.4364 - val_mae: 0.5214 - 716ms/epoch - 2ms/step
# Epoch 75/100
# 425/425 - 1s - loss: 0.1683 - mae: 0.2778 - val_loss: 0.3801 - val_mae: 0.4618 - 694ms/epoch - 2ms/step
# Epoch 76/100
# 425/425 - 1s - loss: 0.1682 - mae: 0.2775 - val_loss: 0.4072 - val_mae: 0.5026 - 712ms/epoch - 2ms/step
# Epoch 77/100
# 425/425 - 1s - loss: 0.1684 - mae: 0.2772 - val_loss: 0.4465 - val_mae: 0.5393 - 680ms/epoch - 2ms/step
# Epoch 78/100
# 425/425 - 1s - loss: 0.1677 - mae: 0.2759 - val_loss: 0.4541 - val_mae: 0.5427 - 690ms/epoch - 2ms/step
# Epoch 79/100
# 425/425 - 1s - loss: 0.1691 - mae: 0.2775 - val_loss: 0.4548 - val_mae: 0.5455 - 700ms/epoch - 2ms/step
# Epoch 80/100
# 425/425 - 1s - loss: 0.1683 - mae: 0.2763 - val_loss: 0.4314 - val_mae: 0.5257 - 684ms/epoch - 2ms/step
# Epoch 81/100
# 425/425 - 1s - loss: 0.1669 - mae: 0.2750 - val_loss: 0.4272 - val_mae: 0.5258 - 745ms/epoch - 2ms/step
# Epoch 82/100
# 425/425 - 1s - loss: 0.1665 - mae: 0.2752 - val_loss: 0.3856 - val_mae: 0.4896 - 724ms/epoch - 2ms/step
# Epoch 83/100
# 425/425 - 1s - loss: 0.1666 - mae: 0.2757 - val_loss: 0.4017 - val_mae: 0.4812 - 710ms/epoch - 2ms/step
# Epoch 84/100
# 425/425 - 1s - loss: 0.1671 - mae: 0.2771 - val_loss: 0.3682 - val_mae: 0.4582 - 717ms/epoch - 2ms/step
# Epoch 85/100
# 425/425 - 1s - loss: 0.1659 - mae: 0.2749 - val_loss: 0.3996 - val_mae: 0.4975 - 1s/epoch - 2ms/step
# Epoch 86/100
# 425/425 - 1s - loss: 0.1667 - mae: 0.2761 - val_loss: 0.3685 - val_mae: 0.4524 - 1s/epoch - 2ms/step
# Epoch 87/100
# 425/425 - 1s - loss: 0.1655 - mae: 0.2745 - val_loss: 0.3865 - val_mae: 0.4859 - 1s/epoch - 3ms/step
# Epoch 88/100
# 425/425 - 1s - loss: 0.1647 - mae: 0.2735 - val_loss: 0.3798 - val_mae: 0.4742 - 796ms/epoch - 2ms/step
# Epoch 89/100
# 425/425 - 1s - loss: 0.1648 - mae: 0.2736 - val_loss: 0.3769 - val_mae: 0.4784 - 689ms/epoch - 2ms/step
# Epoch 90/100
# 425/425 - 1s - loss: 0.1653 - mae: 0.2737 - val_loss: 0.3809 - val_mae: 0.4586 - 679ms/epoch - 2ms/step
# Epoch 91/100
# 425/425 - 1s - loss: 0.1654 - mae: 0.2739 - val_loss: 0.3866 - val_mae: 0.4915 - 700ms/epoch - 2ms/step
# Epoch 92/100
# 425/425 - 1s - loss: 0.1639 - mae: 0.2720 - val_loss: 0.4508 - val_mae: 0.5079 - 683ms/epoch - 2ms/step
# Epoch 93/100
# 425/425 - 1s - loss: 0.1645 - mae: 0.2732 - val_loss: 0.3637 - val_mae: 0.4508 - 672ms/epoch - 2ms/step
# Epoch 94/100
# 425/425 - 1s - loss: 0.1629 - mae: 0.2714 - val_loss: 0.4089 - val_mae: 0.4856 - 708ms/epoch - 2ms/step
# Epoch 95/100
# 425/425 - 1s - loss: 0.1639 - mae: 0.2725 - val_loss: 0.3936 - val_mae: 0.4888 - 706ms/epoch - 2ms/step
# Epoch 96/100
# 425/425 - 1s - loss: 0.1631 - mae: 0.2724 - val_loss: 0.4568 - val_mae: 0.5429 - 695ms/epoch - 2ms/step
# Epoch 97/100
# 425/425 - 1s - loss: 0.1648 - mae: 0.2739 - val_loss: 0.4589 - val_mae: 0.5486 - 717ms/epoch - 2ms/step
# Epoch 98/100
# 425/425 - 1s - loss: 0.1629 - mae: 0.2726 - val_loss: 0.4200 - val_mae: 0.4964 - 682ms/epoch - 2ms/step
# Epoch 99/100
# 425/425 - 1s - loss: 0.1642 - mae: 0.2734 - val_loss: 0.4206 - val_mae: 0.5073 - 669ms/epoch - 2ms/step
# Epoch 100/100
# 425/425 - 1s - loss: 0.1621 - mae: 0.2706 - val_loss: 0.4039 - val_mae: 0.4977 - 680ms/epoch - 2ms/step

# %%
y_pred = model.evaluate(X_test, y_test)
# Out:
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2683 - mae: 0.3572

# %%
y_pred = model.predict(X_test)  # Get the actual predictions
y_pred = y_pred.flatten() # Flatten the predictions to a 1D array

top_5_pred = y_pred[:5]
top_5_true = y_test[:5]

print("\nTop 5 Predictions vs Original Values:")
for i in range(5):
    print(f"Prediction: {top_5_pred[i]:.2f}, Original: {top_5_true[i]:.2f}")
# Out:
# 94/94 [==============================] - 0s 2ms/step
#
# Top 5 Predictions vs Original Values:
# Prediction: 1.57, Original: 1.23
# Prediction: 0.11, Original: -0.26
# Prediction: 0.54, Original: 0.57
# Prediction: 1.54, Original: 1.10
# Prediction: -1.17, Original: -1.10
